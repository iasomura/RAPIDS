# %% [markdown]
# ## 1. プログラムの概要と目的
#
# ### 概要
# このプログラムは、複数の証明書フォーマット（PEM、DER、PKCS#7）に対応した証明書解析ツールです。データベースから証明書データを取得し、証明書からドメイン情報を抽出・分析します。また、証明書の有効性やマルチドメイン証明書の割合、フォールバック解析の利用状況などを統計的に評価し、可視化する機能を備えています。
#
# ### 目的
# - **証明書データの解析:** 証明書内のドメイン情報を抽出し、証明書の特性を分析する。
# - **フォールバック解析:** 証明書の解析に失敗した場合、代替データを利用して再解析を試みることで解析の成功率を向上させる。
# - **エラーハンドリング:** 証明書解析時のエラーを分類・集計し、エラー統計をレポートする。
# - **データベース連携:** PostgreSQL データベースから証明書データを取得し、動的に解析を行う。
# - **解析結果の可視化:** Matplotlib と日本語フォントを利用し、証明書の有効性やフォールバックの利用状況をグラフとして出力する。
#
# ---
#
# ## 2. 主な機能と特徴
#
# ### 主な機能
# 1. **証明書データのクリーニングと変換**
#    - 文字列形式で与えられた証明書データを適切に処理し、PEM/DER/PKCS#7 の各形式に応じたバイト列に変換。
#
# 2. **ドメイン抽出**
#    - **SAN (Subject Alternative Name) 拡張**: 証明書内の SAN 拡張から DNS 名を抽出。
#    - **Common Name (CN)**: SAN に含まれていない場合、CN からもドメイン名を取得。
#
# 3. **フォールバック解析**
#    - プライマリ証明書の解析に失敗した場合、フォールバックの証明書データを利用して再解析を試みる。
#    - フォールバック成功時には、その情報を結果に反映。
#
# 4. **データベース連携**
#    - PostgreSQL データベースから証明書データを取得し、証明書の解析を動的に実施。
#
# 5. **詳細な結果の出力**
#    - 抽出したドメイン情報、エラー内容、フォールバック利用状況などを CSV ファイルとして保存。
#
# 6. **解析結果の可視化**
#    - Matplotlib と日本語フォントを利用して以下の内容をグラフ化：
#      - 証明書の有効性（有効/無効の割合）
#      - ドメイン数の分布
#      - フォールバック利用状況
#
# ---
#
# ### 特徴
# - **多様な証明書形式に対応**
#   - PEM、DER、PKCS#7 の形式を自動判別し、適切に解析を実施。
#
# - **エラーハンドリングの充実**
#   - 発生するエラーを詳細に分類（ASN.1 パースエラー、16進数形式エラー、解析エラーなど）。
#   - エラー統計を集計し、解析全体の健全性をモニタリング可能。
#
# - **フォールバック機能による信頼性向上**
#   - 一度の失敗で解析を諦めず、代替データを用いた再解析を実施。
#
# - **柔軟な設定**
#   - 設定ファイル（JSON形式）により、データベース接続情報などを簡単に変更可能。
#
# - **グラフィカルなレポート**
#   - 統計情報やエラー統計、ドメイン数のヒストグラムなどを視覚的に把握しやすい形式で出力。
#
# ---
#
# ## 3. プログラムの処理フロー
#
# 1. **データベースから証明書データを取得**
#    - PostgreSQL から `https_certificate_body` と `https_certificate_all` を取得。
#    - `status = 7` の条件を満たすレコードのみ処理対象とする。
#
# 2. **証明書データの解析**
#    - `clean_cert_data` 関数で証明書データのクリーニング（PEM/DER/PKCS#7 に応じた適切な処理）。
#    - `load_certificate_from_data` 関数で X.509 証明書をパース。
#    - `extract_domains` 関数でドメイン情報を抽出。
#
# 3. **フォールバック解析の適用**
#    - `extract_domains_with_fallback` 関数により、プライマリ証明書が解析に失敗した場合、フォールバックデータで再解析を試行。
#
# 4. **統計情報の算出**
#    - 有効な証明書数、無効な証明書数、マルチドメイン証明書の割合、フォールバック利用率などを計算。
#
# 5. **解析結果の保存**
#    - CSV ファイルとして詳細な解析結果を保存。
#
# 6. **解析結果の可視化**
#    - 証明書の有効性、ドメイン数の分布、フォールバック利用状況をグラフとして出力。
#
# ---
#
# ## 4. 出力情報
#
# ### 4.1 サマリー情報
# - 総証明書数
# - 有効な証明書数と割合
# - 無効な証明書数と割合
# - マルチドメイン証明書の数と割合
# - 証明書あたりの平均ドメイン数・最大ドメイン数
# - フォールバック利用証明書数と割合
#
# ### 4.2 エラー統計
# - 総処理証明書数
# - 成功した証明書解析の割合
# - エラーの内訳（ASN.1 エラー、HEX エラー、解析エラー、ドメインなしエラーなど）
#
# ### 4.3 可視化（Matplotlib）
# - 証明書の有効性（円グラフ）
# - ドメイン数の分布（ヒストグラム）
# - フォールバック利用状況（円グラフ）
#
# ---
#
# ## 5. 想定される利用シーン
#
# - **証明書管理**: 大量の証明書データを効率的に管理し、適切なドメインが設定されているか確認する。
# - **セキュリティ監査**: 有効期限や証明書の構造を分析し、不正な証明書が含まれていないかチェックする。
# - **データ品質評価**: 証明書データベースの品質を評価し、エラー率やマルチドメイン証明書の割合を把握する。
#
# ---
#
# ## 6. まとめ
# このプログラムは、複数形式の証明書データを解析し、証明書の有効性やドメイン情報を詳細に分析するためのツールです。フォールバック解析やエラーハンドリング機能を備えており、証明書データベースの品質管理やセキュリティ監査に有用です。さらに、統計情報を可視化することで、証明書データの傾向を直感的に把握することができます。

# %%
import pandas as pd
import re
from sqlalchemy import create_engine
import json
from cryptography import x509
from cryptography.hazmat.backends import default_backend
from cryptography.hazmat.primitives import serialization
from cryptography.hazmat.primitives.serialization import pkcs7

# データベース設定の読み込み
config_path = '/home/asomura/waseda/nextstep/RAPIDS/config/database.json'
with open(config_path) as f:
    config = json.load(f)['database']

def get_engine(db_name: str) -> create_engine:
    """データベース接続エンジンを取得"""
    host = 'localhost'
    return create_engine(
        f'postgresql://{config["user"]}:{config["password"]}@{host}/{db_name}'
    )

def clean_pem_format(cert_data: str) -> str:
    """PEMフォーマットの証明書をクリーンアップ"""
    cert_data = cert_data.strip()
    cert_data = re.sub(r'[^A-Za-z0-9+/=\n-]', '', cert_data)
    cert_data = cert_data.replace('\\n', '\n')
    return cert_data

def load_certificate_from_data(data: bytes):
    """PEM, DER, PKCS#7（PEM/DER）の各形式に対応して証明書をロード"""
    try:
        return x509.load_pem_x509_certificate(data, default_backend())
    except Exception:
        try:
            return x509.load_der_x509_certificate(data, default_backend())
        except Exception:
            try:
                if b'-----BEGIN PKCS7-----' in data:
                    return pkcs7.load_pem_pkcs7_certificates(data)[0]
                else:
                    return pkcs7.load_der_pkcs7_certificates(data)[0]
            except Exception as e:
                print(f"[ERROR] 証明書のロード失敗: {str(e)}")
                return None

def analyze_certificates_from_db(db_name: str):
    """証明書データを取得し、パース可能な証明書の数を確認"""
    engine = get_engine(db_name)
    
    query = """
    SELECT id, https_certificate_body FROM website_data
    WHERE status = 7 AND https_certificate_body IS NOT NULL
    """
    df_cert = pd.read_sql_query(query, engine)
    total_records = len(df_cert)
    processed_cert_count = 0
    
    for idx, row in df_cert.iterrows():
        data = clean_pem_format(row['https_certificate_body']).encode('utf-8')
        cert = load_certificate_from_data(data)
        if cert:
            processed_cert_count += 1
        else:
            print(f"[DEBUG] 証明書パース失敗: レコードID {row['id']}")
    
    print(f"[INFO] {db_name} - 取得レコード数: {total_records}, 処理成功数: {processed_cert_count}")

# 実行
for db in ['website_data', 'normal_sites']:
    analyze_certificates_from_db(db)
# Out:
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987292
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980376
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981783
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981425
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983021
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981428
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981072
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981779
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983539
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983955
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980377
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981426
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981780
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984840
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981073
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 858804
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981427
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 579556
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980378
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983022
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981781
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981929
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981142
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980379
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981463
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981074
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981429
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983540
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981784
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983956
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987302
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980380
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981075
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981464
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981144
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981430
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983541
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981785
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981145
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983023
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981786
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987926
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980381
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981076
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981465
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981431
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983542
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984841
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981146
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981077
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980382
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 977461
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975877
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981787
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981466
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983957
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981432
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983000
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981788
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 854520
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 979303
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980383
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981467
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981078
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981147
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983024
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974951
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983543
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980384
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981789
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981433
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975889
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983841
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981079
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981468
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 977564
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980385
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981148
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981080
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 986442
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981434
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983544
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980386
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983025
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981469
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980387
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981081
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981149
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981790
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981151
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974954
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984537
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980388
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983958
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981082
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 866235
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981435
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981470
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 985465
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 863851
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980389
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983545
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984842
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981437
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983842
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981083
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981152
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981471
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981791
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980390
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981438
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981085
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981153
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983026
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981472
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981154
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983546
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980391
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981086
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981155
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981439
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987303
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983959
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981156
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981473
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980392
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981792
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981087
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987927
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981474
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983843
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980393
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981440
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984538
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981088
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981157
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980394
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981441
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983027
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981158
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981475
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975878
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981793
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975049
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983547
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975084
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975024
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974895
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981089
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974909
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980395
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 985466
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975892
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983960
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974994
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981442
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975119
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974993
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981159
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975032
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981476
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975029
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980396
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 863318
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975102
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981090
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984843
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 977392
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981794
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983548
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981477
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975069
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980397
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981091
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 865978
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974898
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981161
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975059
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 883191
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983844
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981444
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974913
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983028
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974910
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974901
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980398
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981162
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981092
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974962
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980790
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981478
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974959
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974977
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983017
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974922
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980399
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981163
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981093
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981795
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981445
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981164
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981479
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983549
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980400
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980791
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981094
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980401
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981165
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981446
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983029
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983961
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980402
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981480
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984539
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980403
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981095
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981166
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974981
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981447
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981796
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974969
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975043
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974918
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974906
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974965
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975075
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975100
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975031
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975107
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974947
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974946
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983361
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974957
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974987
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975053
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984844
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974985
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975055
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975113
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975077
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975044
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974950
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974989
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974970
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975120
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974961
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974968
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975099
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975036
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974955
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974990
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975076
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975097
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975025
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975115
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975091
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974900
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975060
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975885
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974899
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974897
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975105
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975078
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974919
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974986
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 977460
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975022
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974908
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980404
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974943
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974911
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 977463
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975116
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975064
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975104
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980799
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974933
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 977459
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 975034
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974917
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974944
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974916
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 977462
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974931
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 974974
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981167
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981481
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980405
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981450
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983550
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980406
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983019
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983845
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981096
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981168
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981482
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980407
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987928
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 985467
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980408
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981169
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 862168
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980805
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981452
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981483
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983030
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980803
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981097
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980409
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981797
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983362
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987306
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983962
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981170
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 986443
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980410
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981484
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983551
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980804
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981098
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980412
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983020
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980411
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981171
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981453
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981485
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984540
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983846
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981798
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981099
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984845
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983031
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981172
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981454
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983552
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980806
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981486
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980463
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981100
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983363
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981126
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981173
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983963
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981101
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981799
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983032
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981174
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980464
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981487
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981102
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980807
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983553
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981456
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983847
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983964
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984044
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984045
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980465
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981103
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980808
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981176
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 985129
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981800
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981488
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983554
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980466
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981104
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987430
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981105
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983033
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980467
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981460
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983364
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981106
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 985468
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981107
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983848
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980809
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981177
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981489
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983965
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983555
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984541
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980468
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981108
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981490
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987307
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980810
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981801
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 866307
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987929
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981178
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 606548
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981109
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981491
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980469
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981179
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983034
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981110
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981492
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980470
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983365
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980811
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981180
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981802
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981622
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 986444
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981111
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983556
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983849
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983966
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980471
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981493
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 985130
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984046
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981112
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981624
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983366
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 611591
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981494
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980812
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981181
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981803
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983035
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980472
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983557
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981113
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981625
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984542
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 610814
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981495
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981804
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981114
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983967
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981182
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 985469
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980473
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983367
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983850
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980813
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 611671
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981115
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987431
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981496
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981626
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981183
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981497
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983036
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983558
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981116
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983968
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980474
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981805
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980814
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981627
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980475
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984543
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984047
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981117
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 985131
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981498
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981184
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983368
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980815
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981628
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981499
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981806
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980476
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981118
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 859254
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983037
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981185
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981500
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983559
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983851
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980477
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981119
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983969
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980816
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981186
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981501
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983369
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981120
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981807
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983038
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981629
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980478
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981502
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980817
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981121
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981187
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 854147
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983560
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981503
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981122
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983852
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983970
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987309
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980479
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987930
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981188
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980818
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981504
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983039
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981123
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984544
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981124
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981808
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 857055
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981630
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980480
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981189
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981505
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987432
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983561
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980819
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983040
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981190
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981631
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981125
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983370
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981506
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980481
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981809
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 985132
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983971
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983853
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 985470
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980820
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 979576
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981127
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981191
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981632
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980482
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983042
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981507
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983371
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983562
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981633
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981192
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980821
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981128
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980483
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981810
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981508
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984049
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981193
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983043
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983563
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980822
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981129
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980484
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981634
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981509
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981194
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981811
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981635
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983372
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983854
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980823
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981130
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980485
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983044
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983972
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981195
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983564
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987433
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981131
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981510
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983045
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980486
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981196
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981636
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980824
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984545
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981812
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981132
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980487
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981511
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981197
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983973
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980825
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981133
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981637
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980488
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983046
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983855
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981198
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981134
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981512
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981813
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980826
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980489
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983373
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983565
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981135
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981513
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 985133
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980490
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981638
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987434
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980827
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981136
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981814
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 983047
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981199
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980491
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981514
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 984546
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981137
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 987311
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980828
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 985471
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 980492
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 981815
# ...
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60104
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60313
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60410
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 59981
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60250
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60389
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61566
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 59984
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 59985
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60369
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 59986
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 59992
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60220
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60456
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 59996
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60105
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60151
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60471
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60676
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60474
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63674
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60477
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62892
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60480
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60483
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60486
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60489
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60479
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62212
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60484
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60500
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60485
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60490
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63445
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61570
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63894
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60491
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60492
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60721
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60493
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62895
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60495
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60496
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63162
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62216
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60498
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63449
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60499
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60502
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60503
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62896
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63163
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60681
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62218
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60506
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60510
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60511
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60512
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63687
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60513
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63164
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60514
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62219
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63451
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60515
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60516
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60524
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60541
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60560
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60534
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60555
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60517
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60519
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60520
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61584
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60528
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60525
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62222
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63690
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60529
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63165
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60530
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60531
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63454
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61587
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60684
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62225
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60532
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62907
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60533
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60586
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60535
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60538
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62909
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60543
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63166
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61591
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60641
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60628
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60545
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63167
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62912
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61592
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60546
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63898
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60547
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63692
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60552
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63168
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60587
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60549
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60551
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63899
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60554
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61596
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62233
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60558
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60563
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60559
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62926
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60562
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60564
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60565
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60566
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63465
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60567
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63169
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62927
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60568
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60569
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61610
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60611
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60644
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60619
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63466
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62240
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60572
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60573
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60574
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60577
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60576
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61613
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60583
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60584
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60585
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63694
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60597
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60593
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60592
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60594
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61617
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62931
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63903
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60598
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60599
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63170
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60600
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61619
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60601
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62249
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63171
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60602
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60603
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60604
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61620
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60605
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60606
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60607
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60609
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62937
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63697
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60612
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61623
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62256
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61624
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60622
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60613
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63481
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60614
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60615
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60617
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60621
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60623
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60624
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60625
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60627
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60626
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60630
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63173
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60633
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61628
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63702
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60632
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60634
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60636
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60638
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62268
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63175
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 62269
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63485
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60640
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63705
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60645
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 61631
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60646
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 60648
# [ERROR] 証明書のロード失敗: Unable to parse PKCS7 data
# [DEBUG] 証明書パース失敗: レコードID 63176
# [INFO] normal_sites - 取得レコード数: 9591, 処理成功数: 0

# %%
# --- 追加機能: SSL/TLS証明書の認証レベル分析機能 ---
from cryptography.x509.oid import ExtensionOID, NameOID

def analyze_cert_authentication(self, cert: x509.Certificate) -> Dict:
    """
    証明書の認証レベル（DV/OV/EV）を判別し、OV/EVの場合は組織情報の抽出と
    不審な特徴のチェックを行う。
    """
    # デフォルトはDV（Domain Validation）
    cert_type = "DV"
    org_info = None

    # 1. EV判定：証明書ポリシー拡張に EV 証明書の典型的なOID (2.23.140.1.1) が含まれていれば
    try:
        cert_policies = cert.extensions.get_extension_for_oid(ExtensionOID.CERTIFICATE_POLICIES).value
        for policy in cert_policies:
            if policy.policy_identifier.dotted_string == "2.23.140.1.1":
                cert_type = "EV"
                break
    except x509.ExtensionNotFound:
        # CERTIFICATE_POLICIES拡張が存在しない場合はスルー
        pass

    # 2. OV判定：サブジェクトに組織名（O）が存在すれば、DVではなくOVとする（ただしEVが既に判定されている場合はそのまま）
    try:
        subject = cert.subject
        org_attributes = subject.get_attributes_for_oid(NameOID.ORGANIZATION_NAME)
        if org_attributes and cert_type != "EV":
            cert_type = "OV"
    except Exception:
        pass

    # 3. OV/EVの場合は、組織情報の抽出と不審な特徴のチェックを実施
    if cert_type in ("OV", "EV"):
        try:
            get_attr = lambda oid: subject.get_attributes_for_oid(oid)[0].value if subject.get_attributes_for_oid(oid) else ""
            org_name = get_attr(NameOID.ORGANIZATION_NAME)
            org_unit = get_attr(NameOID.ORGANIZATIONAL_UNIT_NAME)
            country = get_attr(NameOID.COUNTRY_NAME)
            state = get_attr(NameOID.STATE_OR_PROVINCE_NAME)
            locality = get_attr(NameOID.LOCALITY_NAME)

            org_info = {
                "organization": org_name,
                "organizational_unit": org_unit,
                "country": country,
                "state": state,
                "locality": locality,
                "suspicious_flags": []
            }

            # 不審な特徴のチェック例

            # 例1: 組織名が極端に短い
            if org_name and len(org_name.strip()) < 3:
                org_info["suspicious_flags"].append("組織名が短すぎる")

            # 例2: 組織名に英数字以外の割合が高い場合
            if org_name:
                alnum_count = sum(1 for c in org_name if c.isalnum())
                if len(org_name) > 0 and alnum_count / len(org_name) < 0.5:
                    org_info["suspicious_flags"].append("組織名の構成が不自然")

            # 例3: 国コードが通常の2文字でない場合
            if country and len(country.strip()) != 2:
                org_info["suspicious_flags"].append("国コードが不正")
        except Exception as e:
            org_info = {"error": f"組織情報抽出エラー: {str(e)}"}

    return {
        "cert_type": cert_type,
        "organization_info": org_info
    }

# CertificateAnalyzerクラスに新メソッド analyze_cert_authentication を追加
CertificateAnalyzer.analyze_cert_authentication = analyze_cert_authentication

def analyze_authentication_levels(self, db_name: str) -> Dict:
    """
    指定したDBから証明書を取得し、各証明書について認証レベル（DV/OV/EV）の判別、
    組織情報抽出を実施した上で統計情報を集計する。
    """
    print(f"\n{db_name} の認証レベル分析を開始...")
    query = """
        SELECT domain, https_certificate_body, https_certificate_all
        FROM website_data 
        WHERE status = 7 
          AND (https_certificate_body IS NOT NULL OR https_certificate_all IS NOT NULL);
    """
    engine = self.get_engine(db_name)
    df = pd.read_sql_query(query, engine)
    print(f"取得したレコード数: {len(df)}")
    
    results = []
    dv_count = 0
    ov_count = 0
    ev_count = 0
    unknown_count = 0
    
    for _, row in df.iterrows():
        primary_cert = row['https_certificate_body']
        fallback_cert = row['https_certificate_all']
        try:
            cert = self.load_certificate_from_data(primary_cert)
        except Exception as e:
            if fallback_cert:
                try:
                    cert = self.load_certificate_from_data(fallback_cert)
                except Exception as e2:
                    results.append({
                        'original_domain': row['domain'],
                        'cert_auth': "Parse Error",
                        'details': f"Primary error: {str(e)} / Fallback error: {str(e2)}"
                    })
                    continue
            else:
                results.append({
                    'original_domain': row['domain'],
                    'cert_auth': "Parse Error",
                    'details': str(e)
                })
                continue

        auth_info = self.analyze_cert_authentication(cert)
        cert_type = auth_info.get("cert_type", "Unknown")
        if cert_type == "DV":
            dv_count += 1
        elif cert_type == "OV":
            ov_count += 1
        elif cert_type == "EV":
            ev_count += 1
        else:
            unknown_count += 1

        results.append({
            'original_domain': row['domain'],
            'cert_auth': cert_type,
            'organization_info': auth_info.get("organization_info")
        })
    
    total_cert = len(results)
    return {
        'total_certificates': total_cert,
        'dv_count': dv_count,
        'ov_count': ov_count,
        'ev_count': ev_count,
        'unknown_count': unknown_count,
        'dv_ratio': dv_count / total_cert if total_cert > 0 else 0,
        'ov_ratio': ov_count / total_cert if total_cert > 0 else 0,
        'ev_ratio': ev_count / total_cert if total_cert > 0 else 0,
        'unknown_ratio': unknown_count / total_cert if total_cert > 0 else 0,
        'results': results
    }

# CertificateAnalyzerクラスに新メソッド analyze_authentication_levels を追加
CertificateAnalyzer.analyze_authentication_levels = analyze_authentication_levels

def print_authentication_summary(self, auth_results: Dict, db_name: str):
    """認証レベル分析結果のサマリーを表示する"""
    print(f"\n=== {db_name} の証明書認証レベル分析サマリー ===")
    total = auth_results.get('total_certificates', 0)
    print(f"総証明書数: {total:,}")
    print(f"DV証明書数: {auth_results.get('dv_count', 0):,} ({auth_results.get('dv_ratio', 0)*100:.1f}%)")
    print(f"OV証明書数: {auth_results.get('ov_count', 0):,} ({auth_results.get('ov_ratio', 0)*100:.1f}%)")
    print(f"EV証明書数: {auth_results.get('ev_count', 0):,} ({auth_results.get('ev_ratio', 0)*100:.1f}%)")
    if auth_results.get('unknown_count', 0) > 0:
        print(f"不明または解析エラー: {auth_results.get('unknown_count', 0):,} ({auth_results.get('unknown_ratio', 0)*100:.1f}%)")

# CertificateAnalyzerクラスに新メソッド print_authentication_summary を追加
CertificateAnalyzer.print_authentication_summary = print_authentication_summary

# --- テスト/実行例 ---
def run_authentication_analysis():
    # 設定ファイルのパス（既存と同じ設定を利用）
    config_path = '/home/asomura/waseda/nextstep/RAPIDS/config/database.json'
    analyzer = CertificateAnalyzer(config_path)
    
    # website_data および normal_sites の両DBで認証レベル分析を実施
    auth_results_website = analyzer.analyze_authentication_levels('website_data')
    auth_results_normal = analyzer.analyze_authentication_levels('normal_sites')
    
    analyzer.print_authentication_summary(auth_results_website, 'website_data')
    analyzer.print_authentication_summary(auth_results_normal, 'normal_sites')
    
    # 必要に応じて、詳細結果をCSVへ保存する処理などを追加可能です

if __name__ == "__main__":
    run_authentication_analysis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # --- 追加機能: SSL/TLS証明書の認証レベル分析機能 ---
#       2 from cryptography.x509.oid import ExtensionOID, NameOID
# ----> 4 def analyze_cert_authentication(self, cert: x509.Certificate) -> Dict:
#       5     """
#       6     証明書の認証レベル（DV/OV/EV）を判別し、OV/EVの場合は組織情報の抽出と
#       7     不審な特徴のチェックを行う。
#       8     """
#       9     # デフォルトはDV（Domain Validation）
#
# NameError: name 'Dict' is not defined

# %% [markdown]
# # SSL/TLS証明書認証レベルの可視化プログラムの分析
#
# ## 1. 概要
# 本プログラムは、**SSL/TLS証明書の認証レベル（DV/OV/EV）を分析し、結果を可視化**します。
# 認証レベルの分析には `CertificateAnalyzer` クラスを利用し、`website_data` および `normal_sites` のデータベースから証明書情報を取得・解析します。
# 可視化は **パイチャート（割合）** と **棒グラフ（件数）** の2種類で行います。
#
# ## 2. 主要な機能
# ### 2.1 認証レベル分析の実行
# #### `analyze_authentication_levels(db_name: str) -> Dict`
# - `CertificateAnalyzer` クラスの `analyze_authentication_levels` メソッドを利用し、データベースから証明書情報を取得。
# - 証明書の認証レベル（**DV: Domain Validation, OV: Organization Validation, EV: Extended Validation**）を判定。
# - 解析結果を辞書形式で格納し、以下の統計情報を提供：
#   - `dv_count`: DV証明書の数
#   - `ov_count`: OV証明書の数
#   - `ev_count`: EV証明書の数
#   - `unknown_count`: 不明または解析エラーの証明書数
#   - 各認証レベルの割合 (`dv_ratio`, `ov_ratio`, `ev_ratio`, `unknown_ratio`)
#
# ### 2.2 認証レベルの可視化
# #### `plot_authentication_results(auth_results: Dict, db_name: str)`
# - **パイチャート**
#   - `matplotlib.pyplot.pie()` を利用し、各認証レベルの割合を可視化。
#   - `labels=['DV', 'OV', 'EV', 'Unknown']` を設定し、異なる色 (`colors=['#66b3ff', '#99ff99', '#ffcc99', '#ff9999']`) で識別。
# - **棒グラフ**
#   - `matplotlib.pyplot.bar()` を利用し、各認証レベルの証明書数を可視化。
#   - 各バーの上に件数を表示し、視覚的に比較しやすくする。
#
# ### 2.3 メイン処理の流れ
# 1. 設定ファイル (`database.json`) をロードし、`CertificateAnalyzer` のインスタンスを作成。
# 2. `website_data` および `normal_sites` の証明書認証レベルを分析。
# 3. 分析結果を `plot_authentication_results()` を用いて可視化。
#
# ## 3. メリット・特徴
# - **SSL/TLS証明書の認証レベルを可視化**
#   → DV, OV, EV 証明書の比率を簡単に把握可能
# - **異なるデータベースの結果を比較可能**
#   → `website_data` と `normal_sites` の認証レベルの違いを分析
# - **グラフの見やすさを向上**
#   → **パイチャート（割合）** と **棒グラフ（件数）** の両方を使用
#
# ## 4. まとめ
# 本プログラムにより、SSL/TLS証明書の認証レベルを統計・可視化し、サイトのセキュリティ評価を容易に行うことができます。
# 企業や研究機関での **証明書分析・監査** に役立つツールとなるでしょう。

# %%
# %% [code]
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# 設定ファイルのパス（既存のものを利用）
config_path = '/home/asomura/waseda/nextstep/RAPIDS/config/database.json'

# CertificateAnalyzerのインスタンスを生成（既に追加した認証レベル分析機能が利用可能なはず）
analyzer = CertificateAnalyzer(config_path)

# website_data および normal_sites それぞれで認証レベル分析を実施
auth_results_website = analyzer.analyze_authentication_levels('website_data')
auth_results_normal = analyzer.analyze_authentication_levels('normal_sites')

def plot_authentication_results(auth_results, db_name):
    """
    認証レベルの分析結果をパイチャートと棒グラフで可視化する。
    """
    # 各認証レベルの件数を抽出
    dv = auth_results.get('dv_count', 0)
    ov = auth_results.get('ov_count', 0)
    ev = auth_results.get('ev_count', 0)
    unknown = auth_results.get('unknown_count', 0)
    
    labels = ['DV', 'OV', 'EV', 'Unknown']
    counts = [dv, ov, ev, unknown]
    colors = ['#66b3ff', '#99ff99', '#ffcc99', '#ff9999']
    
    # 2種類のグラフを並べて表示するためにサブプロットを用意
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    
    # パイチャート：割合表示
    axes[0].pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors)
    axes[0].set_title(f'{db_name} - 認証レベル割合')
    
    # 棒グラフ：件数表示
    bars = axes[1].bar(labels, counts, color=colors)
    axes[1].set_title(f'{db_name} - 認証レベル件数')
    axes[1].set_ylabel("件数")
    
    # 各棒の上に件数を表示
    for bar in bars:
        height = bar.get_height()
        axes[1].text(bar.get_x() + bar.get_width()/2, height, f'{int(height)}', 
                     ha='center', va='bottom', fontsize=12)
    
    plt.tight_layout()
    plt.show()

# website_data の認証レベル分析結果を可視化
plot_authentication_results(auth_results_website, 'website_data')

# normal_sites の認証レベル分析結果を可視化
plot_authentication_results(auth_results_normal, 'normal_sites')
